# %% [markdown]
# Why Pandas
# - Flexibility of Python ( more than Excel)
# - Working with big data

# %% [markdown]
# In this video we walk through many of the fundamental concepts to use the Python Pandas Data Science Library. We start off by installing pandas and loading in an example csv. We then look at different ways to read the data. Read a column, rows, specific cell, etc. Also ways to read data based on conditioning. We then move into some more advanced ways to sort & filter data. We look at making conditional changes to our data. We also start doing aggregate stats using the groupby function. We finished the video talking about how you would work with a very large dataset (many gigabytes)
#
# I realized as I upload this video there are some additional things I want to talk about in a later video. The first thing that comes to mind immediately is using the apply() function on a dataframe to alter the data using a custom or lambda function. If you have questions on this or anything else before I get around to making  a part 2, feel free to write me a note in the comments.

# %%
import pandas as pd

# %%
# Import Csv
df=pd.read_csv("D:\DA on da way\OverAll Course Lv1\Học thêm cá nhân\Luyen python truoc khoa 3\pokemon_data.csv")
# Import txt ( tab seperated) then conver it to table.
df_txt=pd.read_csv("D:\DA on da way\OverAll Course Lv1\Học thêm cá nhân\Luyen python truoc khoa 3\pokemon_data_txt.txt", delimiter='\t')
print(df_txt)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # 1. Reading Data in pandas

# %%
# Question : loc and iloc difference
# xem lai ham for...in...a anh TracHoangAn

## Read headers
df.columns

## Read each columns top 5 
df['Name'][0:5]
## read 2 columns

## Read each columns( for text)
# loc : smae loc + finding specific in our dataset that isnt just interger based, isnt just the specific rows, it's based on more textual information
df.loc[df['Type 1']=='Grass'] 
# access specific rows
#df.iloc[0:5]


#for index, row in df.iterrows():
#    print(index, row['Name'])

# Read specific location (R,C)
#df.iloc[2,2]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Step 2: Sorting/ Describe Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# Sort
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Sort tu 2 cot. cot 1 asc, cot 2 desc
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Step 3 : Make some change in the data

# %%
#ranking pokemon by sum + add new column total
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# Drop some specific column :

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Add columns in # way [row, columns]
# - axis : add horizontally
# - axis = 0 adding vertically

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)
#chuyen cot total before or after the cluster ( removee column to another place)

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
df.head(5)
#( above is just visual thing, be cafereful when hardcode things in number, can use index)
# Out:
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    591  45      49
# 1  2                Ivysaur  Grass  Poison      False    750  60      62
# 2  3               Venusaur  Grass  Poison      False    970  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False   1170  80     100
# 4  4             Charmander   Fire     NaN      False    553  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %% [markdown]
# # Step 4 : Saving our Data ( Exporting into Desired Format)

# %%
# Saving with different format, where is it stored ?
#saving as csv
#df.to_csv('modified.csv', index=False)
#df.to_excel('modified.xlsx', index=False)
df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# # Step 5 : Filtering data

# %%
advanced stuff
# Out:
#   Cell In[27], line 1
#     advanced stuff
#              ^
# SyntaxError: invalid syntax

# %%
# Want to filter >2 columns, use () for each filter
df.loc[(df['Type 1']=='Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    591   45      49
# 1      2                Ivysaur  Grass  Poison      False    750   60      62
# 2      3               Venusaur  Grass  Poison      False    970   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   1170   80     100
# 48    43                 Oddish  Grass  Poison      False    610   45      50
# 49    44                  Gloom  Grass  Poison      False    750   60      65
# 50    45              Vileplume  Grass  Poison      False    930   75      80
# 75    69             Bellsprout  Grass  Poison      False    560   50      75
# 76    70             Weepinbell  Grass  Poison      False    725   65      90
# 77    71             Victreebel  Grass  Poison      False    910   80     105
# 344  315                Roselia  Grass  Poison      False    735   50      60
# ...

# %%
# filter either tyoe 1 = x or type 2 = y. use |
df.loc[(df['Type 1']=='Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    591   45      49
# 1      2                Ivysaur  Grass  Poison      False    750   60      62
# 2      3               Venusaur  Grass  Poison      False    970   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   1170   80     100
# 48    43                 Oddish  Grass  Poison      False    610   45      50
# 49    44                  Gloom  Grass  Poison      False    750   60      65
# 50    45              Vileplume  Grass  Poison      False    930   75      80
# 75    69             Bellsprout  Grass  Poison      False    560   50      75
# 76    70             Weepinbell  Grass  Poison      False    725   65      90
# 77    71             Victreebel  Grass  Poison      False    910   80     105
# 344  315                Roselia  Grass  Poison      False    735   50      60
# ...

# %%
new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2'] == 'Poison') & (df['HP']>30)]

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    591   45      49
# 1      2                Ivysaur  Grass  Poison      False    750   60      62
# 2      3               Venusaur  Grass  Poison      False    970   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   1170   80     100
# 48    43                 Oddish  Grass  Poison      False    610   45      50
# 49    44                  Gloom  Grass  Poison      False    750   60      65
# 50    45              Vileplume  Grass  Poison      False    930   75      80
# 75    69             Bellsprout  Grass  Poison      False    560   50      75
# 76    70             Weepinbell  Grass  Poison      False    725   65      90
# 77    71             Victreebel  Grass  Poison      False    910   80     105
# 344  315                Roselia  Grass  Poison      False    735   50      60
# ...

# %%
# reset new index : reset_index()

# %%
# Tao them 1 cot index moi
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#       #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0     1              Bulbasaur  Grass  Poison      False    591   45      49
# 1     2                Ivysaur  Grass  Poison      False    750   60      62
# 2     3               Venusaur  Grass  Poison      False    970   80      82
# 3     3  VenusaurMega Venusaur  Grass  Poison      False   1170   80     100
# 4    43                 Oddish  Grass  Poison      False    610   45      50
# 5    44                  Gloom  Grass  Poison      False    750   60      65
# 6    45              Vileplume  Grass  Poison      False    930   75      80
# 7    69             Bellsprout  Grass  Poison      False    560   50      75
# 8    70             Weepinbell  Grass  Poison      False    725   65      90
# 9    71             Victreebel  Grass  Poison      False    910   80     105
# 10  315                Roselia  Grass  Poison      False    735   50      60
# ...

# %%
# Filter all the name that ontain Mega
- str.contains('')

# %%
# ko chua Mega
df.loc[~df['Name'].str.contains('Mega')]
# chua Mega
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1            Bulbasaur    Grass  Poison      False    591   45      49
# 1      2              Ivysaur    Grass  Poison      False    750   60      62
# 2      3             Venusaur    Grass  Poison      False    970   80      82
# 4      4           Charmander     Fire     NaN      False    553   39      52
# 5      5           Charmeleon     Fire     NaN      False    730   58      64
# ..   ...                  ...      ...     ...        ...    ...  ...     ...
# 794  718     Zygarde50% Forme   Dragon  Ground       True   1105  108     100
# 795  719              Diancie     Rock   Fairy       True   1150   50     100
# 797  720  HoopaHoopa Confined  Psychic   Ghost       True   1130   80     110
# 798  720   HoopaHoopa Unbound  Psychic    Dark       True   1280   80     160
# 799  721            Volcanion     Fire   Water       True   1130   80     110
#
# ...

# %%
# to see the type 1 either grass or fire
# regular expression la gi ?
import re
df.loc[df['Type 1'].str.contains('Fire|Grass', flasg regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    591   45      49
# 1      2                Ivysaur  Grass  Poison      False    750   60      62
# 2      3               Venusaur  Grass  Poison      False    970   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   1170   80     100
# 4      4             Charmander   Fire     NaN      False    553   39      52
# ..   ...                    ...    ...     ...        ...    ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False    666   62      50
# 736  668                 Pyroar   Fire  Normal      False    908   86      68
# 740  672                 Skiddo  Grass     NaN      False    648   66      65
# 741  673                 Gogoat  Grass     NaN      False    994  123     100
# 799  721              Volcanion   Fire   Water       True   1130   80     110
#
# ...

# %%
# Similar to upper, but dont care about caplocks as we use flags
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    591   45      49
# 1      2                Ivysaur  Grass  Poison      False    750   60      62
# 2      3               Venusaur  Grass  Poison      False    970   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   1170   80     100
# 4      4             Charmander   Fire     NaN      False    553   39      52
# ..   ...                    ...    ...     ...        ...    ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False    666   62      50
# 736  668                 Pyroar   Fire  Normal      False    908   86      68
# 740  672                 Skiddo  Grass     NaN      False    648   66      65
# 741  673                 Gogoat  Grass     NaN      False    994  123     100
# 799  721              Volcanion   Fire   Water       True   1130   80     110
#
# ...

# %%
# all pokemon nam estart with pik
df.loc[df['Name'].str.contains('pi[a-z]', flags=re.I, regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Legendary  Total   HP  \
# 13    10                 Caterpie       Bug       NaN      False    345   45
# 20    16                   Pidgey    Normal    Flying      False    446   40
# 21    17                Pidgeotto    Normal    Flying      False    627   63
# 22    18                  Pidgeot    Normal    Flying      False    857   83
# 23    18      PidgeotMega Pidgeot    Normal    Flying      False   1037   83
# 30    25                  Pikachu  Electric       NaN      False    550   35
# 42    37                   Vulpix      Fire       NaN      False    533   38
# 76    70               Weepinbell     Grass    Poison      False    725   65
# 84    78                 Rapidash      Fire       NaN      False    895   65
# 136  127                   Pinsir       Bug       NaN      False    915   65
# 137  127        PinsirMega Pinsir       Bug    Flying      False   1095   65
# ...

# %%
# pi appear in the middle, them ^
df.loc[df['Name'].str.contains('^pi[a-z]', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary  Total   HP  \
# 20    16               Pidgey    Normal    Flying      False    446   40
# 21    17            Pidgeotto    Normal    Flying      False    627   63
# 22    18              Pidgeot    Normal    Flying      False    857   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False   1037   83
# 30    25              Pikachu  Electric       NaN      False    550   35
# 136  127               Pinsir       Bug       NaN      False    915   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False   1095   65
# 186  172                Pichu  Electric       NaN      False    350   20
# 219  204               Pineco       Bug       NaN      False    565   50
# 239  221            Piloswine       Ice    Ground      False    850  100
# 438  393               Piplup     Water       NaN      False    588   53
# 558  499              Pignite      Fire  Fighting      False    781   90
# ...

# %%
# Step 6 : Conditional Changes

# %%
# If type 1 = Fire, change to Flamer
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    591  45
# 1      2                Ivysaur    Grass  Poison      False    750  60
# 2      3               Venusaur    Grass  Poison      False    970  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False   1170  80
# 4      4             Charmander     Fire     NaN      False    553  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True   1150  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True   1290  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True   1130  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True   1280  80
# 799  721              Volcanion     Fire   Water       True   1130  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation Type1
# ...

# %%
# if type 1 = Fire, then Legendary = True
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    591  45
# 1      2                Ivysaur    Grass  Poison      False    750  60
# 2      3               Venusaur    Grass  Poison      False    970  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False   1170  80
# 4      4             Charmander     Fire     NaN       True    553  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True   1150  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True   1290  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True   1130  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True   1280  80
# 799  721              Volcanion     Fire   Water       True   1130  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation Type1
# ...

# %%
df.drop(columns = 'Type1')
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    591  45
# 1      2                Ivysaur    Grass  Poison      False    750  60
# 2      3               Venusaur    Grass  Poison      False    970  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False   1170  80
# 4      4             Charmander     Fire     NaN       True    553  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True   1150  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True   1290  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True   1130  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True   1280  80
# 799  721              Volcanion     Fire   Water       True   1130  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
# multiple condition can be modified at a time
#if total > 500
df=pd.read_csv('modified.csv')
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Legendary  \
# 0             0    1              Bulbasaur    Grass  Poison      False
# 1             1    2                Ivysaur    Grass  Poison      False
# 2             2    3               Venusaur    Grass  Poison      False
# 3             3    3  VenusaurMega Venusaur    Grass  Poison      False
# 4             4    4             Charmander     Fire     NaN      False
# ..          ...  ...                    ...      ...     ...        ...
# 795         795  719                Diancie     Rock   Fairy       True
# 796         796  719    DiancieMega Diancie     Rock   Fairy       True
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost       True
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark       True
# 799         799  721              Volcanion     Fire   Water       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %% [markdown]
# # Step 6 : Aggregate Statistics ( Group by)

# %%
# Count average of HP + Attack of Pokemon then see which type is stronger than the other type
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Legendary  \
# 0             0    1              Bulbasaur    Grass  Poison      False
# 1             1    2                Ivysaur    Grass  Poison      False
# 2             2    3               Venusaur    Grass  Poison      False
# 3             3    3  VenusaurMega Venusaur    Grass  Poison      False
# 4             4    4             Charmander     Fire     NaN      False
# ..          ...  ...                    ...      ...     ...        ...
# 795         795  719                Diancie     Rock   Fairy       True
# 796         796  719    DiancieMega Diancie     Rock   Fairy       True
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost       True
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark       True
# 799         799  721              Volcanion     Fire   Water       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10016\3320615934.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
#           Unnamed: 0           #  Legendary        Total         HP  \
# Type 1
# Dragon    521.843750  474.375000   0.375000  1018.031250  83.312500
# Normal    351.581633  319.173469   0.020408   731.816327  77.275510
# Fairy     494.529412  449.529412   0.058824   777.764706  74.117647
# Ground    392.312500  356.281250   0.125000   811.093750  73.781250
# Water     333.312500  303.089286   0.035714   794.946429  72.062500
# Ice       465.666667  423.541667   0.083333   803.458333  72.000000
# Flying    746.500000  677.750000   0.500000   867.500000  70.750000
# ...

# %%
df['count'] = 1
#just count column
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
# group by multiple columns
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
# wwhen you work with big data. grooup by sum can help you to squeeze your data. Make it readable

# %%
# Working with large amounts of data | vd 20 gygabytes.
# pandas allows you to read data likne that

# %%
for df in pd=pd.read_csv('modifies.csv', chunksize=5)
    print("CHUNK DF")
    print(df)
# 5 rows are being part at a time
# Out:
#   Cell In[11], line 1
#     for df in pd=pd.read_csv('modifies.csv', chunksize=5)
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # DO IT AGAIN! 18 07 2023

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\DA on da way\OverAll Course Lv1\Học thêm cá nhân\Luyen python truoc khoa 3\pokemon_data.csv")

# How to read file txt with '\' delimiter
poketxt = pd.read_csv("D:\DA on da way\OverAll Course Lv1\Học thêm cá nhân\Luyen python truoc khoa 3\pokemon_data_txt.txt", delimiter='\t')
poketxt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
poke.head()
poke.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# # Reading data in Pandas

# %% [markdown]
# - iloc : filtering data

# %%
# Read Headers
df.columns

# Read each columns : 
df[['Name','HP','Attack','Defense']]
df[['Name']]

# Read each row
df.iloc[0:4] #range of row, using index

display(df.loc[(df.HP >=90) & (df.Attack >150)]) # condiion


display(df.loc[df['Type 1'] == 'Grass'])

#iloc :  stans for int location + to grab specific location

# Read a specific location(r,c)

# Iterrate :
#for index, row in df.iterrows():
#    print(index, row['Type 1'])
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 141  130    GyaradosMega Gyarados    Water      Dark   95     155      109
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 268  248  TyranitarMega Tyranitar     Rock      Dark  100     164      150
# 313  289                  Slaking   Normal       NaN  150     160      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 454  409                Rampardos     Rock       NaN   97     165       60
# 494  445    GarchompMega Garchomp   Dragon    Ground  108     170      115
# 543  486                Regigigas   Normal       NaN  110     160      110
# 711  646       KyuremBlack Kyurem   Dragon       Ice  125     170      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 141       70      130     81           1      False
# ...

# %%
# Homework Review

# loc bang iloc va loc
df.iloc[1,2]
df.loc[(df.HP >100) & (df.Attack <10)]
df['Sum HP & Attack'] = df.iloc[:,4:6].sum(axis=1)
df.head()

# Add column
#df['Total']= df.iloc[:,4:10].sum(axis=1)

#cols=list(df.columns)
#df=df[cols[0:4] + [cols[-1]] + cols[4:12]]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Sum HP & Attack
# 0       65     45           1      False               94
# 1       80     60           1      False              122
# 2      100     80           1      False              162
# 3      120     80           1      False              180
# 4       50     65           1      False               91

# %%
for index, row in df.iterrows():
    print(index, row['Type 1'])
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Grass
# 4 Fire
# 5 Fire
# 6 Fire
# 7 Fire
# 8 Fire
# 9 Water
# 10 Water
# 11 Water
# 12 Water
# 13 Bug
# 14 Bug
# 15 Bug
# 16 Bug
# 17 Bug
# 18 Bug
# 19 Bug
# 20 Normal
# 21 Normal
# 22 Normal
# 23 Normal
# 24 Normal
# 25 Normal
# 26 Normal
# 27 Normal
# 28 Poison
# 29 Poison
# 30 Electric
# 31 Electric
# 32 Ground
# 33 Ground
# 34 Poison
# 35 Poison
# 36 Poison
# 37 Poison
# 38 Poison
# 39 Poison
# 40 Fairy
# 41 Fairy
# 42 Fire
# 43 Fire
# 44 Normal
# 45 Normal
# 46 Poison
# 47 Poison
# 48 Grass
# 49 Grass
# 50 Grass
# 51 Bug
# 52 Bug
# 53 Bug
# 54 Bug
# 55 Ground
# 56 Ground
# 57 Normal
# 58 Normal
# 59 Water
# 60 Water
# 61 Fighting
# 62 Fighting
# 63 Fire
# 64 Fire
# 65 Water
# 66 Water
# 67 Water
# 68 Psychic
# 69 Psychic
# 70 Psychic
# 71 Psychic
# 72 Fighting
# 73 Fighting
# 74 Fighting
# 75 Grass
# 76 Grass
# 77 Grass
# 78 Water
# 79 Water
# 80 Rock
# 81 Rock
# 82 Rock
# 83 Fire
# 84 Fire
# 85 Water
# 86 Water
# 87 Water
# 88 Electric
# ...

# %% [markdown]
# # Soring / Describing Data

# %%
df.describe()

df.sort_values('Name', ascending=False)

df.sort_values(['Name', 'HP'], ascending=[1,0])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to data

# %%
# Drop columns
# df=df.drop(columns=['name'])

# %%
# Add column
df['Total']= df.iloc[:,4:10].sum(axis=1)

cols=list(df.columns)
df=df[cols[0:4] + [cols[-1]] + cols[4:12]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # Saving our Data ( Exporting into Desired Format)

# %%
df.to_csv('modified.csv', index=False, sep='\t')

# %% [markdown]
# # Filtering Data ( advanced)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum HP & Attack
# ...

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Defense'] > 60) & (df['Attack'] >= 45)]
new_df.reset_index(drop=True, inplace=True)

new_df

# filter words contains "Mega" or reverse Mega(~)
df.loc[~df['Name'].str.contains('Mega')]
# y nghia: 
#  drop= True : drop index column cu
# inplace=True : update luon vao file new_df


# Regular expression : filtering data based on certain textual pattern ( very very strong)

import re

# filter Type 1 contains grass| fire, ignore caplock casee
df.loc[df['Type 1'].str.contains('grass|fire', flags=re.I, regex=True)]

# filter Type 1 contains Pi
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)].reset_index(drop=True)
# Out:
#       #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 0    16               Pidgey    Normal    Flying   40      45       40
# 1    17            Pidgeotto    Normal    Flying   63      60       55
# 2    18              Pidgeot    Normal    Flying   83      80       75
# 3    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 4    25              Pikachu  Electric       NaN   35      55       40
# 5   127               Pinsir       Bug       NaN   65     125      100
# 6   127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 7   172                Pichu  Electric       NaN   20      40       15
# 8   204               Pineco       Bug       NaN   50      65       90
# 9   221            Piloswine       Ice    Ground  100     100       80
# 10  393               Piplup     Water       NaN   53      51       53
# 11  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# # Conditional Changes

# %%
# Neu Type 1 = 'Flamer, thi trong column type1, doi thanh 'Flamer'
df.loc[df['Type 1']== 'Fire', 'Type 1'] = 'Flamer'

# Tra lai du lieu cu
df.loc[df['Type 1']== 'Flamer', 'Type 1'] = 'Fire'

# Use condition to set parameter of another column.
# VD : If Type 1 = 'Flamer', value of column 'Legendary' = True

df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True

# Change multiple parameter at a time
df.loc[df['Speed'] >= 50, ['Generation','Legendary']] = ['Test','Another Test']

df=pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum HP & Attack
# ...

# %% [markdown]
# # Aggregate Statistics ( Groupby)

# %%
# the avg(hp,attack) of all pokemon grouped by which type they are
df.groupby(['Type 1']).mean()[['HP','Attack']].sort_values(['HP','Attack'], ascending=[1,0])

#count
df['count']=1
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_184\571733146.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Type 1']).mean()[['HP','Attack']].sort_values(['HP','Attack'], ascending=[1,0])
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amounts of data
